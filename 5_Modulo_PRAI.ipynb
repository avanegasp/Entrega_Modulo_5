# %% [markdown]
# <a href="https://colab.research.google.com/github/avanegasp/Entrega_Modulo_5/blob/main/5_Modulo_PRAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
risk = pd.read_csv('https://raw.githubusercontent.com/avanegasp/mi_proyecto_unicatalu-a/main/SP%20500%20ESG%20Risk%20Ratings.csv')

# %%
risk.head(3)
# Out:
#   Symbol                         Name  \
# 0      A     Agilent Technologies Inc
# 1    AAL  American Airlines Group Inc
# 2    AAP       Advance Auto Parts Inc
#
#                                              Address             Sector  \
# 0  5301 Stevens Creek Boulevard\nSanta Clara, CA ...         Healthcare
# 1  1 Skyview Drive\nFort Worth, TX 76155\nUnited ...        Industrials
# 2  4200 Six Forks Road\nRaleigh, NC 27609\nUnited...  Consumer Cyclical
#
#                  Industry Full Time Employees  \
# 0  Diagnostics & Research              18,000
# 1                Airlines             132,500
# 2        Specialty Retail              40,000
#
#                                          Description  Total ESG Risk score  \
# 0  Agilent Technologies, Inc. provides applicatio...                  15.0
# 1  American Airlines Group Inc., through its subs...                  29.0
# 2  Advance Auto Parts, Inc. provides automotive r...                  12.0
#
# ...

# %%
risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Symbol                  503 non-null    object
#  1   Name                    503 non-null    object
#  2   Address                 501 non-null    object
#  3   Sector                  501 non-null    object
#  4   Industry                501 non-null    object
#  5   Full Time Employees     496 non-null    object
#  6   Description             501 non-null    object
#  7   Total ESG Risk score    433 non-null    float64
#  8   Environment Risk Score  433 non-null    float64
#  9   Governance Risk Score   433 non-null    float64
#  10  Social Risk Score       433 non-null    float64
#  11  Controversy Level       404 non-null    object
#  12  Controversy Score       433 non-null    float64
#  13  ESG Risk Percentile     433 non-null    object
# ...

# %%
risk.describe()
# Out:
#        Total ESG Risk score  Environment Risk Score  Governance Risk Score  \
# count            433.000000              433.000000             433.000000
# mean              21.422633                5.678984               6.673903
# std                7.264458                5.339965               2.201049
# min                7.000000                0.000000               3.000000
# 25%               16.000000                1.500000               5.000000
# 50%               21.000000                3.800000               6.000000
# 75%               26.000000                8.900000               7.700000
# max               46.000000               25.000000              15.500000
#
#        Social Risk Score  Controversy Score
# count         433.000000         433.000000
# mean            9.045035           1.896074
# std             3.813788           0.940748
# min             1.100000           0.000000
# 25%             6.600000           1.000000
# ...

# %%
risk.describe(include='object')
# Out:
#        Symbol                      Name  \
# count     503                       503
# unique    503                       503
# top         A  Agilent Technologies Inc
# freq        1                         1
#
#                                                   Address      Sector  \
# count                                                 501         501
# unique                                                498          11
# top     1211 Avenue of the Americas\nNew York, NY 1003...  Technology
# freq                                                    2          75
#
#                             Industry Full Time Employees  \
# count                            501                 496
# unique                           114                 398
# top     Utilities—Regulated Electric              25,000
# freq                              23                   5
#
#                                               Description Controversy Level  \
# ...

# %%
#Creo una copia independiente de risk
copy_ind_risk = risk.copy()

# %%
#Genero una copia de mi dataset
copy_risk = risk

# %%
copy_risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Symbol                  503 non-null    object
#  1   Name                    503 non-null    object
#  2   Address                 501 non-null    object
#  3   Sector                  501 non-null    object
#  4   Industry                501 non-null    object
#  5   Full Time Employees     496 non-null    object
#  6   Description             501 non-null    object
#  7   Total ESG Risk score    433 non-null    float64
#  8   Environment Risk Score  433 non-null    float64
#  9   Governance Risk Score   433 non-null    float64
#  10  Social Risk Score       433 non-null    float64
#  11  Controversy Level       404 non-null    object
#  12  Controversy Score       433 non-null    float64
#  13  ESG Risk Percentile     433 non-null    object
# ...

# %%
#Se elimina la columna 'Symbol'
risk_2 = risk.drop(columns=['Symbol'])

# %%
risk_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    503 non-null    object
#  1   Address                 501 non-null    object
#  2   Sector                  501 non-null    object
#  3   Industry                501 non-null    object
#  4   Full Time Employees     496 non-null    object
#  5   Description             501 non-null    object
#  6   Total ESG Risk score    433 non-null    float64
#  7   Environment Risk Score  433 non-null    float64
#  8   Governance Risk Score   433 non-null    float64
#  9   Social Risk Score       433 non-null    float64
#  10  Controversy Level       404 non-null    object
#  11  Controversy Score       433 non-null    float64
#  12  ESG Risk Percentile     433 non-null    object
#  13  ESG Risk Level          376 non-null    object
# ...

# %% [markdown]
# ## Análisis Univariado del dataset original

# %% [markdown]
# ### Controversy Score

# %%
sns.boxplot(data=risk_2, x='Controversy Score')
# Out:
# <Axes: xlabel='Controversy Score'>

# %%
#La media y mediana son tan cercanas que no se nota la mediana en el gráfico
risk_2['Controversy Score'].describe()
# Out:
# count    433.000000
# mean       1.896074
# std        0.940748
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        5.000000
# Name: Controversy Score, dtype: float64

# %%
sns.countplot(data=risk_2, x='Controversy Score', order=[2.0,1.0,3.0,0.0,4.0,5.0])
# Out:
# <Axes: xlabel='Controversy Score', ylabel='count'>

# %%
#Hay que tener en cuenta la relación de controversy level y controversy score *revisar
risk.loc[risk['Controversy Score']>3].head(1)
# Out:
#    Symbol                     Name  \
# 45   ATVI  Activision Blizzard Inc
#
#                                               Address                  Sector  \
# 45  2701 Olympic Boulevard Building B\nSanta Monic...  Communication Services
#
#                           Industry Full Time Employees  \
# 45  Electronic Gaming & Multimedia              13,000
#
#                                           Description  Total ESG Risk score  \
# 45  Activision Blizzard, Inc., together with its s...                  19.0
#
#     Environment Risk Score  Governance Risk Score  Social Risk Score  \
# 45                     0.2                    6.3               12.5
#
#    Controversy Level  Controversy Score ESG Risk Percentile ESG Risk Level
# 45              High                4.0     22nd percentile            Low

# %% [markdown]
# ### Total ESG Risk score

# %%
sns.boxplot(data=risk, x='Total ESG Risk score')
# Out:
# <Axes: xlabel='Total ESG Risk score'>

# %%
#Se hace un filtro para revisar los datos atípicos pero no se notan números anormales
risk.loc[risk['Total ESG Risk score']> 40]
# Out:
#     Symbol                       Name  \
# 122   CTRA         Coterra Energy Inc
# 200     GE        General Electric Co
# 318    MRO          Marathon Oil Corp
# 357    OXY  Occidental Petroleum Corp
#
#                                                Address       Sector  \
# 122  Three Memorial City Plaza\nSuite 1400 840 Gess...       Energy
# 200  5 Necco Street\nBoston, MA 02210\nUnited State...  Industrials
# 318  990 Town and Country Boulevard\nHouston, TX 77...       Energy
# 357  5 Greenway Plaza\nSuite 110\nHouston, TX 77046...       Energy
#
#                            Industry Full Time Employees  \
# 122                   Oil & Gas E&P                 981
# 200  Specialty Industrial Machinery             172,000
# 318                   Oil & Gas E&P               1,570
# 357                   Oil & Gas E&P              11,973
#
#                                            Description  Total ESG Risk score  \
# ...

# %% [markdown]
# ### Environment Risk Score

# %%
sns.boxplot(data=risk, x='Environment Risk Score')
# Out:
# <Axes: xlabel='Environment Risk Score'>

# %%
risk.loc[risk['Environment Risk Score']> 20].head(2)
# Out:
#     Symbol                Name  \
# 39     APA            Apa Corp
# 122   CTRA  Coterra Energy Inc
#
#                                                Address  Sector       Industry  \
# 39   2000 Post Oak Boulevard\nSuite 100 One Post Oa...  Energy  Oil & Gas E&P
# 122  Three Memorial City Plaza\nSuite 1400 840 Gess...  Energy  Oil & Gas E&P
#
#     Full Time Employees                                        Description  \
# 39                2,273  APA Corporation, through its subsidiaries, exp...
# 122                 981  Coterra Energy Inc., an independent oil and ga...
#
#      Total ESG Risk score  Environment Risk Score  Governance Risk Score  \
# 39                   39.0                    22.0                    8.0
# 122                  46.0                    24.1                    8.8
#
#      Social Risk Score Controversy Level  Controversy Score  \
# 39                 8.9          Moderate                2.0
# ...

# %% [markdown]
# ### Governance Risk Score

# %%
sns.boxplot(data=risk, x='Governance Risk Score')
# Out:
# <Axes: xlabel='Governance Risk Score'>

# %%
risk.loc[risk['Governance Risk Score']> 11].head()
# Out:
#    Symbol                          Name  \
# 7    ACGL        Arch Capital Group Ltd
# 18    AIG  American International Group
# 32    AMP      Ameriprise Financial Inc
# 54    BAC          Bank of America Corp
# 65     BK  Bank of New York Mellon Corp
#
#                                               Address              Sector  \
# 7   Waterloo House\nGround Floor 100 Pitts Bay Roa...  Financial Services
# 18  1271 Avenue of the Americas\nNew York, NY 1002...  Financial Services
# 32  1099 Ameriprise Financial Center\nMinneapolis,...  Financial Services
# 54  Bank of America Corporate Center\n100 North Tr...  Financial Services
# 65  240 Greenwich Street\nNew York, NY 10286\nUnit...  Financial Services
#
#                  Industry Full Time Employees  \
# 7   Insurance—Diversified               5,800
# 18  Insurance—Diversified              26,200
# 32       Asset Management              13,500
# 54      Banks—Diversified             216,000
# ...

# %% [markdown]
# ### Social Risk Score

# %%
sns.boxplot(data=risk, x='Social Risk Score')
# Out:
# <Axes: xlabel='Social Risk Score'>

# %%
risk.loc[risk['Social Risk Score']>19.0]
# Out:
#     Symbol                         Name  \
# 53      BA                    Boeing Co
# 199     GD        General Dynamics Corp
# 302   META   Meta Platforms Inc Class A
# 363    PCG                 P G & E Corp
# 459    UHS  Universal Health Services B
#
#                                                Address  \
# 53   929 Long Bridge Drive\nArlington, VA 22202\nUn...
# 199  11011 Sunset Hills Road\nReston, VA 20190\nUni...
# 302  1601 Willow Road\nMenlo Park, CA 94025\nUnited...
# 363  300 Lakeside Drive\nOakland, CA 94612\nUnited ...
# 459  Universal Corporate Center\n367 South Gulph Ro...
#
#                      Sector                        Industry  \
# 53              Industrials             Aerospace & Defense
# 199             Industrials             Aerospace & Defense
# 302  Communication Services  Internet Content & Information
# 363               Utilities    Utilities—Regulated Electric
# 459              Healthcare         Medical Care Facilities
#
# ...

# %% [markdown]
# ### ESG Risk Level

# %%
sns.countplot(data=risk, x='ESG Risk Level', order=['Medium', 'Low', 'Negligible', 'High', 'Severe'])
# Out:
# <Axes: xlabel='ESG Risk Level', ylabel='count'>

# %% [markdown]
# ### Controversy Level

# %%
sns.countplot(data=risk, x='Controversy Level', order=['Moderate', 'Low','Significant','High','Severe','None' ])
# Out:
# <Axes: xlabel='Controversy Level', ylabel='count'>

# %% [markdown]
# ### ESG Risk Percentile

# %%
sns.countplot(data=risk, x='ESG Risk Percentile')
plt.xticks(rotation=90, ha='right', fontsize=6)
plt.show()

# %%
risk['Environment Risk Score'].value_counts()
# Out:
# 2.0     27
# 0.0     23
# 1.0     20
# 3.0     17
# 0.1     15
#         ..
# 8.5      1
# 10.3     1
# 13.2     1
# 10.4     1
# 8.2      1
# Name: Environment Risk Score, Length: 134, dtype: int64

# %% [markdown]
# Luego de evaluar cada uno de los gráficos, se llega a la conclusión que los datos 'atípicos' se van a tener en cuenta en el análisis porque sí hacen parte de los datos

# %% [markdown]
# ## Detección y corrección de datos atípicos

# %%
#En este código estoy sumando los null de cada columna y están ordenados de manera ascendente
risk_3 = risk_2.isnull().sum().sort_values(ascending = False)

# %%
risk_3
# Out:
# ESG Risk Level            127
# Controversy Level          99
# Total ESG Risk score       70
# Environment Risk Score     70
# Governance Risk Score      70
# Social Risk Score          70
# Controversy Score          70
# ESG Risk Percentile        70
# Full Time Employees         7
# Address                     2
# Sector                      2
# Industry                    2
# Description                 2
# Name                        0
# dtype: int64

# %%
# Hay 77 datos con 1 solo dato faltante y hay 69 datos con 8 datos faltantes por filas
risk_2.isnull().sum(axis = 1).value_counts()
# Out:
# 0     348
# 1      77
# 8      69
# 2       7
# 13      1
# 5       1
# dtype: int64

# %% [markdown]
# ### Eliminación de los null en columnas

# %%
#Valores null por columna y sus valores únicos resultantes de los valores nulos en cada columna
#70 nulos en 6 columnas y así sucesivamente
risk_2.isnull().sum(axis = 0).value_counts()
# Out:
# 70     6
# 2      4
# 0      1
# 7      1
# 99     1
# 127    1
# dtype: int64

# %%
# Probar eliminando todos los null de las columnas
risk_4 = risk_2.dropna(axis=0)

#risk_2.isnull().sum().sort_values(ascending = False)
print(risk_4.shape)
print(risk_2.shape)
# Out:
# (348, 14)
# (503, 14)

# %%
#Se quiere saber cuántos datos quedaron luego de la eliminación
risk_2.size - risk_4.size
# Out:
# 2170

# %%
#Criterio para saber la perdida de data al borrar por columnas
(risk_2.size - risk_4.size)*100/risk_2.size
# Out:
# 30.81510934393638

# %%
risk_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 348 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    348 non-null    object
#  1   Address                 348 non-null    object
#  2   Sector                  348 non-null    object
#  3   Industry                348 non-null    object
#  4   Full Time Employees     348 non-null    object
#  5   Description             348 non-null    object
#  6   Total ESG Risk score    348 non-null    float64
#  7   Environment Risk Score  348 non-null    float64
#  8   Governance Risk Score   348 non-null    float64
#  9   Social Risk Score       348 non-null    float64
#  10  Controversy Level       348 non-null    object
#  11  Controversy Score       348 non-null    float64
#  12  ESG Risk Percentile     348 non-null    object
#  13  ESG Risk Level          348 non-null    object
# ...

# %% [markdown]
# Con esta eliminación de datos en columnas se eliminan el 31% de los datos

# %% [markdown]
# ### Eliminación de Nulos en filas

# %%
# Probar eliminando todos los null de las filas
risk_5 = risk_2.dropna(axis=1)

#risk_2.isnull().sum().sort_values(ascending = False)
print(risk_2.shape)
print(risk_5.shape)
# Out:
# (503, 14)
# (503, 1)

# %%
#Criterio para saber la perdida de data al borrar por filas
round((risk_2.size - risk_5.size)*100/risk_2.size, 0)
# Out:
# 93.0

# %% [markdown]
# Con la eliminación de al menos 1 caracter en cada fila, se ha realizado el borrado del 93% de los datos.

# %% [markdown]
# ### Similitud en los Null

# %% [markdown]
# En base a los valores vistos, se revisa si hay una similitud entre los datos que tienen el mismo de valor nulos (70) y se verifica que son las mismas columnas las que les faltan los mismo valores

# %%
# Con este código se sabe cuantos null hay en cada columna
risk_2[['Total ESG Risk score','Environment Risk Score', 'Governance Risk Score',
      'Social Risk Score','Controversy Score','ESG Risk Percentile']].isnull().sum()
# Out:
# Total ESG Risk score      70
# Environment Risk Score    70
# Governance Risk Score     70
# Social Risk Score         70
# Controversy Score         70
# ESG Risk Percentile       70
# dtype: int64

# %%
#Con este código podemos ver los booleanos en la tabla y confirmar que los datos que faltan
#son los mismos en todas las columnas por lo tanto se pueden eliminar
risk_2[['Total ESG Risk score','Environment Risk Score', 'Governance Risk Score',
      'Social Risk Score','Controversy Score','ESG Risk Percentile']].isnull().head(5)
# Out:
#    Total ESG Risk score  Environment Risk Score  Governance Risk Score  \
# 0                 False                   False                  False
# 1                 False                   False                  False
# 2                 False                   False                  False
# 3                 False                   False                  False
# 4                 False                   False                  False
#
#    Social Risk Score  Controversy Score  ESG Risk Percentile
# 0              False              False                False
# 1              False              False                False
# 2              False              False                False
# 3              False              False                False
# 4              False              False                False

# %%
#Se procede a la eliminación de estos 70 datos en la diferentes columnas
columns_to_clean = ['Total ESG Risk score','Environment Risk Score', 'Governance Risk Score',
      'Social Risk Score','Controversy Score','ESG Risk Percentile']

# %%
risk_6 = risk_2[columns_to_clean].dropna()

# %%
risk_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433 entries, 0 to 502
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Total ESG Risk score    433 non-null    float64
#  1   Environment Risk Score  433 non-null    float64
#  2   Governance Risk Score   433 non-null    float64
#  3   Social Risk Score       433 non-null    float64
#  4   Controversy Score       433 non-null    float64
#  5   ESG Risk Percentile     433 non-null    object
# dtypes: float64(5), object(1)
# memory usage: 23.7+ KB

# %%
#Diferencia entre el tamaño total o sea el número total
registros_eliminados = risk_2.size - risk_6.size

# %%
porcentaje = round(registros_eliminados*100/risk_2.size,0)
porcentaje
# Out:
# 63.0

# %% [markdown]
# Con la eliminación de los datos en cada uno de estas 6 filas, se elimina el 63% del total de los datos.

# %% [markdown]
# ### Filtro
#
# Se realiza la imputación de los valores que tengan más de 5 null en sus filas

# %%
# Filtra nulos que tienen más de 5 nulos en sus filas
risk_2.isnull().sum(axis = 1).value_counts()
# Out:
# 0     348
# 1      77
# 8      69
# 2       7
# 13      1
# 5       1
# dtype: int64

# %%
risk_7 = risk_2[risk.isnull().sum(axis = 1)>5]
#risk_7.info()

# %%
#Total de datos si se eliminara los mayores a 5 datos nulos
risk_2.size - risk_7.size
# Out:
# 6062

# %%
#Criterio para establecer la perdida de data
round((risk_2.size - risk_7.size)*100/risk_2.size,0)
# Out:
# 86.0

# %% [markdown]
# Con esto realizado, eliminar desde 5 null hacía adelante, se procedería a perder el 86% de la data

# %% [markdown]
# ## Imputaciones de datos

# %% [markdown]
# Con base en lo visto anteriormente, una opción es eliminar los null en las columnas con una perdida del 31% de los datos (que sería la menor perdida).
# Sin embargo al ser demasiado el porcentaje de perdida, así que como propuesta se colocarán los datos faltantes según la moda.

# %%
#Se trabajará en base a estos datos null por cada columna
risk_2.isnull().sum().sort_values(ascending = False)
# Out:
# ESG Risk Level            127
# Controversy Level          99
# Total ESG Risk score       70
# Environment Risk Score     70
# Governance Risk Score      70
# Social Risk Score          70
# Controversy Score          70
# ESG Risk Percentile        70
# Full Time Employees         7
# Address                     2
# Sector                      2
# Industry                    2
# Description                 2
# Name                        0
# dtype: int64

# %% [markdown]
# ### Explicación 'Controversy Level'
# Se estudia por cuál medida realizar la imputación de la columna 'Controversy Level'
# - Se estudia hacerlo por la mediana pero los datos cambiarían considerablemente ya que los datos nulos son mayores que los existentes en la mediana que sería 'Significant' y esta ya no sería la mediana sino que cambiaría a 'low'.
# - Se estudia realizarlo por la media pero 'significant' luego de esto ya no sería la media sino sería 'low'
# - Se estudia por la moda para seguir aumentando el valor de 'Moderate' que en este momento es el que más se repite y se toma esto para proceder con la imputación.

# %%
# Obtén los valores únicos en la columna 'Controversy Level'
unique_values = risk_2['Controversy Level'].unique()
unique_values
# Out:
# array(['Low', 'Moderate', 'Significant', 'None', nan, 'High', 'Severe'],
#       dtype=object)

# %%
# Calcula el porcentaje de cada valor único en la columna 'ESG Risk Level'
value_counts = risk_2['Controversy Level'].value_counts()
value_counts
# Out:
# Moderate       197
# Low            105
# Significant     84
# High            15
# Severe           2
# None             1
# Name: Controversy Level, dtype: int64

# %%
value_counts.mode()
# Out:
# 0      1
# 1      2
# 2     15
# 3     84
# 4    105
# 5    197
# Name: Controversy Level, dtype: int64

# %%
value_counts.median()
# Out:
# 49.5

# %%
round(value_counts.mean(),0)
# Out:
# 67.0

# %% [markdown]
# ### Explicación 'ESG Risk Level'
#
# Se estudia por cuál medida realizar la imputación de la columna 'ESG Risk Level'
#
# Se estudia hacerlo por la mediana pero los datos cambiarían considerablemente ya que los datos nulos son mayores que los existentes en la mediana que sería 'Negligible' y esta ya no sería la mediana sino que cambiaría a 'low'.
# Se estudia realizarlo por la media pero 'Negligible' luego de esto ya no sería la media sino sería 'low'
# Se estudia por la moda para seguir aumentando el valor de 'Medium' que en este momento es el que más se repite y se toma esto para proceder con la imputación.

# %%
unique_values_ESG = risk_2['ESG Risk Level'].unique()
unique_values_ESG
# Out:
# array(['Low', nan, 'Negligible', 'Medium', 'Severe', 'High'], dtype=object)

# %%
values_ESG_counts = risk_2['ESG Risk Level'].value_counts()
values_ESG_counts
# Out:
# Medium        134
# Low           131
# Negligible     58
# High           35
# Severe         18
# Name: ESG Risk Level, dtype: int64

# %%
values_ESG_counts.median()
# Out:
# 58.0

# %%
values_ESG_counts.mode()
# Out:
# 0     18
# 1     35
# 2     58
# 3    131
# 4    134
# Name: ESG Risk Level, dtype: int64

# %%
round(values_ESG_counts.mean(),0)
# Out:
# 75.0

# %% [markdown]
# ## Imputación de las demás variables cualitativas del dataframe con su moda correspondiente

# %%
#Dataframe
copy_ind_risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Symbol                  503 non-null    object
#  1   Name                    503 non-null    object
#  2   Address                 501 non-null    object
#  3   Sector                  501 non-null    object
#  4   Industry                501 non-null    object
#  5   Full Time Employees     496 non-null    object
#  6   Description             501 non-null    object
#  7   Total ESG Risk score    433 non-null    float64
#  8   Environment Risk Score  433 non-null    float64
#  9   Governance Risk Score   433 non-null    float64
#  10  Social Risk Score       433 non-null    float64
#  11  Controversy Level       404 non-null    object
#  12  Controversy Score       433 non-null    float64
#  13  ESG Risk Percentile     433 non-null    object
# ...

# %%
#Eliminación de la columna 'Symbol'
copy_ind_risk.drop(columns=['Symbol'])
copy_ind_risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Symbol                  503 non-null    object
#  1   Name                    503 non-null    object
#  2   Address                 501 non-null    object
#  3   Sector                  501 non-null    object
#  4   Industry                501 non-null    object
#  5   Full Time Employees     496 non-null    object
#  6   Description             501 non-null    object
#  7   Total ESG Risk score    433 non-null    float64
#  8   Environment Risk Score  433 non-null    float64
#  9   Governance Risk Score   433 non-null    float64
#  10  Social Risk Score       433 non-null    float64
#  11  Controversy Level       404 non-null    object
#  12  Controversy Score       433 non-null    float64
#  13  ESG Risk Percentile     433 non-null    object
# ...

# %%
def imputar_moda(copy_ind_risk, variables_cualitativas):

  for variable in variables_cualitativas:
    moda_variable = copy_ind_risk[variable].mode()[0]
    copy_ind_risk[variable].fillna(moda_variable, inplace=True)

  return copy_ind_risk

# %%
variables_cualitativas = list(copy_ind_risk.select_dtypes('object').columns)

# %%
copy_ind_risk = imputar_moda(copy_ind_risk = copy_ind_risk,
                      variables_cualitativas = variables_cualitativas
                      )

# %%
copy_ind_risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Symbol                  503 non-null    object
#  1   Name                    503 non-null    object
#  2   Address                 503 non-null    object
#  3   Sector                  503 non-null    object
#  4   Industry                503 non-null    object
#  5   Full Time Employees     503 non-null    object
#  6   Description             503 non-null    object
#  7   Total ESG Risk score    433 non-null    float64
#  8   Environment Risk Score  433 non-null    float64
#  9   Governance Risk Score   433 non-null    float64
#  10  Social Risk Score       433 non-null    float64
#  11  Controversy Level       503 non-null    object
#  12  Controversy Score       433 non-null    float64
#  13  ESG Risk Percentile     503 non-null    object
# ...

# %% [markdown]
# ## Imputación de las variables cuantitativas del dataframe con la moda de cada variable

# %%
def impute_with_mode_col(risk_8, variables_cuantitativas):
    for column in variables_cuantitativas:
            mode_value = risk_8[column].mode()[0]
            risk_8[column].fillna(mode_value, inplace=True)
    return risk_8

# %%
variables_cuantitativas = list(copy_ind_risk.select_dtypes('float64').columns)

# %%
risk_8 = impute_with_mode_col(risk_8 = copy_ind_risk,
                          variables_cuantitativas = variables_cuantitativas
                          )

# %%
risk_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Symbol                  503 non-null    object
#  1   Name                    503 non-null    object
#  2   Address                 503 non-null    object
#  3   Sector                  503 non-null    object
#  4   Industry                503 non-null    object
#  5   Full Time Employees     503 non-null    object
#  6   Description             503 non-null    object
#  7   Total ESG Risk score    503 non-null    float64
#  8   Environment Risk Score  503 non-null    float64
#  9   Governance Risk Score   503 non-null    float64
#  10  Social Risk Score       503 non-null    float64
#  11  Controversy Level       503 non-null    object
#  12  Controversy Score       503 non-null    float64
#  13  ESG Risk Percentile     503 non-null    object
# ...

# %% [markdown]
# ## Matriz de correlación de la variable 'Total ESG Risk score'

# %%
corrmat = risk_8.corr()
corrmat
# Out:
# <ipython-input-751-4bf710afd5f8>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                         Total ESG Risk score  Environment Risk Score  \
# Total ESG Risk score                1.000000                0.735971
# Environment Risk Score              0.735971                1.000000
# Governance Risk Score               0.425575               -0.079605
# Social Risk Score                   0.693480                0.097585
# Controversy Score                   0.320151                0.065417
#
#                         Governance Risk Score  Social Risk Score  \
# Total ESG Risk score                 0.425575           0.693480
# Environment Risk Score              -0.079605           0.097585
# Governance Risk Score                1.000000           0.419793
# ...

# %%
k=10

# %%
cols = corrmat.nlargest(k,'Total ESG Risk score')['Total ESG Risk score'].index

# %%
cols
# Out:
# Index(['Total ESG Risk score', 'Environment Risk Score', 'Social Risk Score',
#        'Governance Risk Score', 'Controversy Score'],
#       dtype='object')

# %%
cm = np.corrcoef(risk_8[cols].values.T)
cm
# Out:
# array([[ 1.        ,  0.73597092,  0.69347976,  0.42557452,  0.32015072],
#        [ 0.73597092,  1.        ,  0.09758521, -0.07960482,  0.06541663],
#        [ 0.69347976,  0.09758521,  1.        ,  0.41979266,  0.40202061],
#        [ 0.42557452, -0.07960482,  0.41979266,  1.        ,  0.20688252],
#        [ 0.32015072,  0.06541663,  0.40202061,  0.20688252,  1.        ]])

# %%
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10},
                 yticklabels=cols.values, xticklabels=cols.values)
plt.title('Matriz de correlación')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, ha='right', fontsize=10)
plt.show()

# %% [markdown]
# Hay concordancia en que las variables con las que más se tiene relación sea con Enviaronment, Social y Governance, puesto que de sus puntuaciones se tiene el Total ESG.

# %% [markdown]
# # Análisis univariados

# %% [markdown]
# ### Total ESG Risk score
#
# El el score más importante para tomar desiciones, puesto que es una métrica que ayuda a los inversionistas, analistas y otras partes interesadas a comprender y comparar el nivel de riesgo relacionado con cuestiones ambientales, sociales y de gobernanza en una entidad o cartera de inversión. Un puntaje más alto (50) indica un mayor nivel de riesgo ESG, mientras que un puntaje más bajo (0) sugiere un menor riesgo en estos aspectos.

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))

sns.boxplot(data=risk_8, x='Total ESG Risk score', ax=axes[0])

sns.histplot(data=risk_8, x='Total ESG Risk score', kde=True, ax=axes[1])


plt.tight_layout()

# %% [markdown]
# Hay una distribución con cola a la derecha asímetrica, cuya probabilidad de estar en el Total ESG Risk score es sobre 17 puntos, esto quiere decir que el nivel de ESG es 'Medium'
# Los outliers son normales y corresponden a 4 empresas con un nivel ESG 'severo'

# %%
outliers_total = risk_8[risk_8['Total ESG Risk score'] > 40]
outliers_total
# Out:
#     Symbol                       Name  \
# 122   CTRA         Coterra Energy Inc
# 200     GE        General Electric Co
# 318    MRO          Marathon Oil Corp
# 357    OXY  Occidental Petroleum Corp
#
#                                                Address       Sector  \
# 122  Three Memorial City Plaza\nSuite 1400 840 Gess...       Energy
# 200  5 Necco Street\nBoston, MA 02210\nUnited State...  Industrials
# 318  990 Town and Country Boulevard\nHouston, TX 77...       Energy
# 357  5 Greenway Plaza\nSuite 110\nHouston, TX 77046...       Energy
#
#                            Industry Full Time Employees  \
# 122                   Oil & Gas E&P                 981
# 200  Specialty Industrial Machinery             172,000
# 318                   Oil & Gas E&P               1,570
# 357                   Oil & Gas E&P              11,973
#
#                                            Description  Total ESG Risk score  \
# ...

# %% [markdown]
# ### ESG Risk Level
#
# Es una clasificación que indica el grado de riesgo ambiental, social y de gobernanza (ESG) al que está expuesta una entidad, empresa o inversión. Los niveles de riesgo ESG generalmente van desde 'despreciado' hasta severo y ofrecen una evaluación cualitativa de la sostenibilidad, la responsabilidad corporativa y la gestión de riesgos en la entidad evaluada. Un nivel de riesgo ESG más alto sugiere un mayor riesgo en términos de ESG.

# %%
sns.histplot(data=risk_8, x='ESG Risk Level', kde=True)

plt.show()

# %% [markdown]
# Tenemos una distribución hacía la derecha con predominio en el dato 'Medium' seguido de 'Low', esto quiere decir que la mayoría de empresas cumplen con la Total ESG.

# %% [markdown]
# ### Enviroment Risk Score
#
# Es una métrica que se utiliza para medir el nivel de riesgo asociado a factores ambientales en una entidad. Esta puntuación se centra específicamente en los riesgos y consideraciones relacionados con el medio ambiente, como el impacto ambiental de las operaciones de una empresa, su huella de carbono, el uso sostenible de recursos naturales y otras prácticas relacionadas con la conservación y la sostenibilidad ambiental.
#
# Un puntaje más alto en el Environment Risk Score indica un mayor nivel de riesgo ambiental asociado con la entidad evaluada.

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))

sns.boxplot(data=risk_8, x='Environment Risk Score', ax=axes[0])
axes[0].set_title('Gráfico Corregido')

sns.histplot(data=risk_8, x='Environment Risk Score', kde=True, ax=axes[1])
axes[1].set_title('Gráfico Corregido')

plt.tight_layout()

# %%
risk_8['Environment Risk Score'].describe()
# Out:
# count    503.000000
# mean       5.166998
# std        5.115045
# min        0.000000
# 25%        1.900000
# 50%        3.000000
# 75%        8.000000
# max       25.000000
# Name: Environment Risk Score, dtype: float64

# %%
outliers_env = risk_8[risk_8['Environment Risk Score'] > 18]
outliers_env.head(3)
# Out:
#     Symbol                Name  \
# 39     APA            Apa Corp
# 122   CTRA  Coterra Energy Inc
# 126    CVX        Chevron Corp
#
#                                                Address  Sector  \
# 39   2000 Post Oak Boulevard\nSuite 100 One Post Oa...  Energy
# 122  Three Memorial City Plaza\nSuite 1400 840 Gess...  Energy
# 126  6001 Bollinger Canyon Road\nSan Ramon, CA 9458...  Energy
#
#                  Industry Full Time Employees  \
# 39          Oil & Gas E&P               2,273
# 122         Oil & Gas E&P                 981
# 126  Oil & Gas Integrated              43,846
#
#                                            Description  Total ESG Risk score  \
# 39   APA Corporation, through its subsidiaries, exp...                  39.0
# 122  Coterra Energy Inc., an independent oil and ga...                  46.0
# 126  Chevron Corporation, through its subsidiaries,...                  38.0
#
#      Environment Risk Score  Governance Risk Score  Social Risk Score  \
# ...

# %% [markdown]
# Esta medida tiene una distribución a la derecha asímetrica, cuya media es de 5 considerada un nivel 'Negligible' o despreciable.
#
# Sus outliers son 13 empresas que tienen más de 18 Environment Risk, consideradas nivel 'Medio' en el total ESG.

# %% [markdown]
# ### Social Risk Score
#
# Es una métrica utilizada para evaluar y medir el nivel de riesgo asociado a factores sociales en una entidad. Esta puntuación se centra específicamente en los riesgos y consideraciones relacionados con temas sociales, como la gestión de relaciones laborales, la diversidad e inclusión, las condiciones laborales, la responsabilidad social corporativa y otros aspectos que afectan a las relaciones entre la entidad y sus empleados, clientes, comunidades y otros stakeholders.
#
#  Un puntaje más alto en el Social Risk Score indica un mayor nivel de riesgo social asociado con la entidad evaluada. *texto en cursiva*

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))

sns.boxplot(data=risk_8, x='Social Risk Score', ax=axes[0])
axes[0].set_title('Gráfico Corregido')

sns.histplot(data=risk_8, x='Social Risk Score', kde=True, ax=axes[1])
axes[1].set_title('Gráfico Corregido')

plt.tight_layout()

# %%
risk_8['Social Risk Score'].describe()
# Out:
# count    503.000000
# mean       8.760437
# std        3.608159
# min        1.100000
# 25%        7.000000
# 50%        8.000000
# 75%       11.000000
# max       21.000000
# Name: Social Risk Score, dtype: float64

# %%
outliers_soc = risk_8[risk_8['Social Risk Score'] > 17]
outliers_soc.head(3)
# Out:
#     Symbol             Name  \
# 53      BA        Boeing Co
# 80     CAT  Caterpillar Inc
# 154    EFX      Equifax Inc
#
#                                                Address       Sector  \
# 53   929 Long Bridge Drive\nArlington, VA 22202\nUn...  Industrials
# 80   1211 Avenue of the Americas\nNew York, NY 1003...   Technology
# 154  1550 Peachtree Street, NW\nAtlanta, GA 30309\n...  Industrials
#
#                          Industry Full Time Employees  \
# 53            Aerospace & Defense             156,000
# 80   Utilities—Regulated Electric              25,000
# 154           Consulting Services              14,000
#
#                                            Description  Total ESG Risk score  \
# 53   The Boeing Company, together with its subsidia...                  35.0
# 80   Alphabet Inc. offers various products and plat...                  34.0
# 154  Equifax Inc. operates as a data, analytics, an...                  26.0
#
# ...

# %% [markdown]
# Esta medida tiene una distribución a la derecha asímetrica, cuya media es de 9 considerada un nivel 'Negligible' o despreciable.
#
# Sus outliers son 3 empresas que tienen más de 17 Social Risk, consideradas nivel 'Medio' en el total ESG.

# %% [markdown]
# ### Governance Risk Score
#
# es una métrica que se utiliza para evaluar y medir el nivel de riesgo asociado a la gobernanza en una entidad. Esta puntuación se centra específicamente en los riesgos y consideraciones relacionados con la gestión y la toma de decisiones corporativas, la estructura de gobierno, la transparencia financiera, la rendición de cuentas y otros aspectos relacionados con la dirección y el control de una entidad.
#
# Un puntaje más alto en el Governance Risk Score indica un mayor nivel de riesgo de gobernanza asociado con la entidad evaluada.

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))

sns.boxplot(data=risk_8, x='Governance Risk Score', ax=axes[0])
axes[0].set_title('Gráfico Corregido')

sns.histplot(data=risk_8, x='Governance Risk Score', kde=True, ax=axes[1])
axes[1].set_title('Gráfico Corregido')

plt.tight_layout()

# %%
risk_8['Governance Risk Score'].describe()
# Out:
# count    503.000000
# mean       6.440954
# std        2.122595
# min        3.000000
# 25%        5.000000
# 50%        5.800000
# 75%        7.400000
# max       15.500000
# Name: Governance Risk Score, dtype: float64

# %%
outliers_gov = risk_8[risk_8['Governance Risk Score'] > 12]
outliers_gov
# Out:
#     Symbol                          Name  \
# 18     AIG  American International Group
# 32     AMP      Ameriprise Financial Inc
# 97    CINF     Cincinnati Financial Corp
# 100    CMA                  Comerica Inc
# 214     GS       Goldman Sachs Group Inc
# 397    RJF   Raymond James Financial Inc
# 465    USB                    Us Bancorp
# 484    WFC              Wells Fargo & Co
#
#                                                Address              Sector  \
# 18   1271 Avenue of the Americas\nNew York, NY 1002...  Financial Services
# 32   1099 Ameriprise Financial Center\nMinneapolis,...  Financial Services
# 97   6200 South Gilmore Road\nFairfield, OH 45014-5...  Financial Services
# 100  Comerica Bank Tower\n1717 Main Street\nDallas,...  Financial Services
# 214  200 West Street\nNew York, NY 10282\nUnited St...  Financial Services
# 397  880 Carillon Parkway\nSaint Petersburg, FL 337...  Financial Services
# ...

# %% [markdown]
# Esta medida tiene una distribución a la derecha asímetrica, cuya media es de 6 considerada un nivel 'Negligible' o despreciable.
#
# Sus outliers son 8 empresas que tienen más de 12 Governance Risk, consideradas nivel 'Medio' en el total ESG.

# %% [markdown]
# ### Controversy Level
#
# Es una clasificación que indica el grado de exposición de una entidad, empresa o inversión a controversias, disputas legales, escándalos u otros problemas éticos. Los niveles de controversia generalmente van desde bajo hasta severo y proporcionan una evaluación cualitativa de la cantidad y gravedad de las controversias y problemas éticos asociados con la entidad. Cuanto mayor sea el nivel de controversia, mayor será el riesgo reputacional y ético.

# %%
sns.histplot(data=risk_8, x='Controversy Level', kde=True)

plt.show()

# %% [markdown]
# Hay una distribución hacía la derecha asimétrica, cuya valor 'Moderate', seguido por 'Low' tienen gran predominio.

# %% [markdown]
# ### Controversy Score
#
# Es una métrica que se utiliza para evaluar y medir el nivel de controversia o controversia asociada a una entidad, empresa o inversión. Esta puntuación refleja la cantidad y la gravedad de las controversias, disputas legales, escándalos o problemas éticos que han involucrado a la entidad en cuestión.
#
# Un puntaje más alto en el Controversy Score indica un mayor nivel de controversia o problemas relacionados con la entidad evaluada.

# %%
# Crear una figura y una matriz de subgráficos con 1 fila y 2 columnas
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # Cambia el tamaño de la figura según tus necesidades

# Primer gráfico
sns.boxplot(data=risk_8, x='Controversy Score',ax=axes[0])
axes[0].set_title('Gráfico corregido')

sns.histplot(data=risk_8, x='Controversy Score', kde=True, ax=axes[1])
axes[1].set_title('Gráfico Corregido')

#Ajustar el espaciado entre los subgráficos
plt.tight_layout()

# %%
risk_8['Controversy Score'].describe()
# Out:
# count    503.000000
# mean       1.910537
# std        0.873440
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        5.000000
# Name: Controversy Score, dtype: float64

# %%
outliers_cs = risk_8[risk_8['Controversy Score'] > 4]
outliers_cs
# Out:
#     Symbol              Name  \
# 363    PCG      P G & E Corp
# 484    WFC  Wells Fargo & Co
#
#                                                Address              Sector  \
# 363  300 Lakeside Drive\nOakland, CA 94612\nUnited ...           Utilities
# 484  420 Montgomery Street\nSan Francisco, CA 94104...  Financial Services
#
#                          Industry Full Time Employees  \
# 363  Utilities—Regulated Electric              26,010
# 484             Banks—Diversified             233,834
#
#                                            Description  Total ESG Risk score  \
# 363  PG&E Corporation, through its subsidiary, Paci...                  35.0
# 484  Wells Fargo & Company, a diversified financial...                  33.0
#
#      Environment Risk Score  Governance Risk Score  Social Risk Score  \
# 363                     8.0                    6.0               21.0
# 484                     1.9                   15.5               15.4
#
# ...

# %% [markdown]
# Hay una ausencia de mediana y media en el gráfico por lo que son casi iguales en número.

# %% [markdown]
# Hay una distribución levemente asímetrica hacía la derecha.
#
# Sus outliers tiene una controversia moderada en empresas cuyo TOTAL ESG es 'severo'

# %% [markdown]
# ### Industry
#
# Hay gran cantidad de industrias en este dataset, por eso se toman las primeras 20 para poder conocer cuáles son las de más presencia en este ranking.
#
# Siendo la industria energética, industrial, sanitaria y tecnológica las que tienen los primeros puestos.

# %%
# Muestra las 20 categorías más frecuentes en 'Industry'
top_industries = risk_8['Industry'].value_counts().head(20)

# Crea un gráfico de barras horizontales
plt.figure(figsize=(12, 8))
sns.barplot(x=top_industries.values, y=top_industries.index, orient='h')
plt.xlabel('Count')
plt.ylabel('Industry')
plt.title('Top 20 Industries')

plt.show()

# %% [markdown]
# # Análisis Bivariado

# %% [markdown]
# ### Total ESG Risk score vs ESG Risk Level

# %%
sns.barplot(data=risk_8, x='ESG Risk Level',y='Total ESG Risk score',
            order=['Negligible','Low','Medium','High','Severe'])
plt.show()

# %% [markdown]
# En el dataset se puede evidenciar la presencia de todos los niveles en las empresas pero hay un predominio de 'Medium' en estas.

# %% [markdown]
# ## Controversy Level vs Controversy Score

# %% [markdown]
# En este gráfico se puede ver la relación que hay entre el 'Controversy Score'y 'Controversy Level'.

# %%
sns.barplot(data=risk_8, x='Controversy Level',y='Controversy Score',
            order=['None', 'Low','Moderate','Significant','High','Severe'])
plt.show()

# %% [markdown]
# Las medida de tendencia central como media, mediana y moda se situan en 'Moderate'

# %% [markdown]
# ## ESG Risk Level vs Total ESG Risk score

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Primer gráfico
sns.barplot(data=risk_8, x='ESG Risk Level', y='Total ESG Risk score',
            order=['Negligible', 'Low', 'Medium', 'High', 'Severe'], ax=axes[0])
axes[0].set_title('Clasificación de ESG')

# Segundo gráfico
sns.barplot(data=risk_8, x='Sector', y='Total ESG Risk score',
            order=['Real Estate', 'Technology','Communication Services','Consumer Cyclical','Healthcare','Financial Services',
                  'Industrials','Consumer Defensive','Basic Materials','Utilities','Energy'], ax=axes[1])

# Rotar las etiquetas del eje x en el segundo gráfico si es necesario
axes[1].tick_params(axis='x', rotation=90)
axes[1].set_title('Nivel de ESG en los sectores')

# Ajustar el espaciado entre los subgráficos
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %% [markdown]
# En estas gráficas podemos apreciar que 'Real Estate' esta en un nivel de riesgo ESG 'Negligible' y las empresas desde 'Industry' hasta 'Energy' están catalogadas como riesgo 'High' y 'Severe'

# %% [markdown]
# ## Total ESG Risk Score vs Sector

# %%
# Ajustar el ancho y el largo de la figura
plt.figure(figsize=(10, 6))  # Ancho: 10 pulgadas, Alto: 6 pulgadas
sns.barplot(data= risk_8, x='Sector',y='Total ESG Risk score')
# Rotar las etiquetas del eje x a 90 grados
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ## Total ESG Risk Score vs Industry

# %%
# Ajustar el ancho y el largo de la figura
plt.figure(figsize=(18, 6))  # Ancho: 10 pulgadas, Alto: 6 pulgadas
sns.barplot(data= risk_8, x='Industry',y='Total ESG Risk score')
# Rotar las etiquetas del eje x a 90 grados
plt.xticks(rotation=90, fontsize=12)

plt.show()

# %% [markdown]
# Como la gráfica pasada es dificil de leer se realiza el análisis de las primeras 20 industrias

# %% [markdown]
# ## Análisis multivariable

# %% [markdown]
# ### Environment Risk Score,	Governance Risk Score,	Social Risk Score vs sector

# %%
import plotly.express as px

# %%
fig_sector = px.bar(risk_8, x='Sector', y=['Environment Risk Score', 'Governance Risk Score', 'Social Risk Score'],
                    title='Sector vs ESG Scores',
                    labels={'value': 'ESG Score', 'variable': 'ESG Component'}
                    )
fig_sector.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# El sector de 'Comunication Services' tiene un componente bajo en el Score ESG mientras que el sector 'Industrial', 'Healthcare','Financial Services' y 'Tecnology' son los que más puntajes tienen esto quiere decir que sus políticas internas no son las mejores.

# %% [markdown]
# ### Environment Risk Score,	Governance Risk Score,	Social Risk Score vs industry

# %%
fig_industry = px.bar(risk_8, x='Industry', y=['Environment Risk Score', 'Governance Risk Score', 'Social Risk Score'],
                    title='Industry vs ESG Scores',
                    labels={'value': 'ESG Score', 'variable': 'ESG Component'}
                    )
# Ajusta el tamaño de la figura
fig_industry.update_layout(
    autosize=False,  # Desactiva el ajuste automático del tamaño
    width=800,       # Define el ancho deseado en píxeles
    height=600,      # Define la altura deseada en píxeles
    font=dict(
        size=10      # Tamaño de la fuente deseado
    )
)
fig_industry.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# En este gráfico se puede notar de manera macro los niveles de puntuación ESG en la industria.
#
# Siendo por mucho las empresas anteriormente descritas como las que más score tienen y por ende menos políticas ESG en sus empresas.

# %% [markdown]
# ### Análisis'Total ESG Risk score', 'Environment Risk Score', 'Governance Risk Score', 'Social Risk Score'

# %%
esg_scores = risk_8[['Total ESG Risk score', 'Environment Risk Score',
                   'Governance Risk Score', 'Social Risk Score']]

# %%
#  Create a single KDE plot for all ESG scores
plt.figure(figsize=(13.6, 6))

# Iterate through each ESG score column and plot its KDE
for i, col in enumerate(esg_scores.columns):
    sns.kdeplot(
        esg_scores[col],
        label=col,
        fill=True
    )

# Add labels and a title
plt.xlabel('ESG Scores')
plt.ylabel('Density')
plt.title('Combined Distribution of ESG Scores')

# Add a legend
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Esta gráfica resume lo visto en el trabajo, hay una gran mayoria de empresas cuyo 'Governance' no es el mejor, en cambio 'Environment' y 'Social' score están casi en el mismo nivel.
#
# Llvando todo esto a que el promedio de ESG Score se situa en menos del 20 puntos, lo que quiere decir que las empresas están nivel 'Medium'
#
# En este nivel, el riesgo ESG es moderado. Puede haber áreas en las que la entidad no cumple completamente con las mejores prácticas en términos de ESG, pero aún así muestra un compromiso general con la sostenibilidad y la gestión de riesgos. Pueden existir áreas de mejora en términos de prácticas ESG.

# %% [markdown]
# ## Conclusiones
#
# 1. Los sectores que presentan más niveles de ESG y por ende son los que menos aportan al bienestar de sus trabajadores y medio que los rodea, son los sectores industriales, sanitarios, finanzas y técnologicos.
# 2. Los sectores que están cumpliendo con las medidas para garatizar una armonia en todos los aspectos son aquellos cuyo recurso humano es lo principal, como los servicios y las bienes raíces.
# 3. En el análisis de estos sectores e industrias aunque hay empresas cuyos niveles están en severo, se puede decir que a nivel general las empresas están colocando en práctica lo mandado por ley y tiene niveles medio en ESG, lo cual no quiere decir que estén bien pero si pueden seguir mejorando.
# 4. La mayoría de las empresas tienen niveles de controversia 'moderado', lo cual quiere decir que en su mayoría han tenido inconvenientes en el ESG.
# 5. El nivel mejor tratado es el de 'Environment', así que las empresas que tienen este nivel bajo prestan atención a mejorar su huella de carbono y tiene más presente que sus impactos no afecten a la naturaleza.
# 6. El nivel que menos está tratado y por ende tiene más puntiación es el social, son empresas cuyos trabajadores no están conformes y por ende las necesidades de estos no estén cubiertas.
# 7. Las empresas que más están creciendo son las que más daños hacen al planeta, son industrias impresindibles para el bienestar del humano, pero a la vez son las que más daños hacen al planeta.

# %% [markdown]
# #Aprendizaje Supervisado
#
# (se basa en ejemplos, le muestro ejemplos(esta casa es de 100 dolares, esta de 300, etc), le digo al modelo de entrada cual es la salida del modelo que tenga

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
risk_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Symbol                  503 non-null    object
#  1   Name                    503 non-null    object
#  2   Address                 503 non-null    object
#  3   Sector                  503 non-null    object
#  4   Industry                503 non-null    object
#  5   Full Time Employees     503 non-null    object
#  6   Description             503 non-null    object
#  7   Total ESG Risk score    503 non-null    float64
#  8   Environment Risk Score  503 non-null    float64
#  9   Governance Risk Score   503 non-null    float64
#  10  Social Risk Score       503 non-null    float64
#  11  Controversy Level       503 non-null    object
#  12  Controversy Score       503 non-null    float64
#  13  ESG Risk Percentile     503 non-null    object
# ...

# %% [markdown]
# ### Partición X y y

# %%
#Se elimina la columna que se va a predecir
X = risk_8.drop(columns = ['Total ESG Risk score'])

#Y = Qué quiero predecir
y = risk_8['Total ESG Risk score']

print('Dimensiones de X: {}'.format(X.shape))
print('Dimensiones de y: {}'.format(y.shape))
# Out:
# Dimensiones de X: (503, 14)
# Dimensiones de y: (503,)

# %%
#Valores sin Total ESG Risk score
X.head()
# Out:
#   Symbol                         Name  \
# 0      A     Agilent Technologies Inc
# 1    AAL  American Airlines Group Inc
# 2    AAP       Advance Auto Parts Inc
# 3   AAPL                    Apple Inc
# 4   ABBV                   Abbvie Inc
#
#                                              Address             Sector  \
# 0  5301 Stevens Creek Boulevard\nSanta Clara, CA ...         Healthcare
# 1  1 Skyview Drive\nFort Worth, TX 76155\nUnited ...        Industrials
# 2  4200 Six Forks Road\nRaleigh, NC 27609\nUnited...  Consumer Cyclical
# 3  One Apple Park Way\nCupertino, CA 95014\nUnite...         Technology
# 4  1 North Waukegan Road\nNorth Chicago, IL 60064...         Healthcare
#
#                      Industry Full Time Employees  \
# 0      Diagnostics & Research              18,000
# 1                    Airlines             132,500
# 2            Specialty Retail              40,000
# 3        Consumer Electronics             164,000
# ...

# %%
#Total ESG Risk score
y
# Out:
# 0      15.0
# 1      29.0
# 2      12.0
# 3      17.0
# 4      28.0
#        ...
# 498    21.0
# 499    27.0
# 500    16.0
# 501    16.0
# 502    18.0
# Name: Total ESG Risk score, Length: 503, dtype: float64

# %%
X = X = risk_8[['Environment Risk Score', 'Governance Risk Score', 'Social Risk Score']]
y = risk_8['Total ESG Risk score']
#Random State que le pide la función que puede tomar valores enteros desde 0 hasta 2**32
#El valor que toma no tiene interpretación, si escojo un valor, SIEMPRE debo escoger ese valor

#El Random State o semilla siempre me traerá el mismo orden (X_test)por eso para este modelo no la debo cambiar
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=99)

# %%
X_train.mean()
# Out:
# Environment Risk Score    5.318182
# Governance Risk Score     6.459375
# Social Risk Score         8.775568
# dtype: float64

# %%
X_test
# Out:
#      Environment Risk Score  Governance Risk Score  Social Risk Score
# 494                     4.0                   11.0               12.0
# 420                    12.0                    6.0                7.0
# 237                     3.0                    9.0                7.0
# 103                     5.5                    4.7               13.4
# 175                     3.8                    4.6                7.3
# ..                      ...                    ...                ...
# 399                     3.0                   11.0               12.0
# 457                    10.9                    5.0               12.9
# 464                     5.9                    6.0                6.6
# 15                     13.0                    5.0                8.0
# 426                     5.8                    7.6               12.5
#
# [151 rows x 3 columns]

# %%
#Valores que se fueron para prueba
X_test.mean()
# Out:
# Environment Risk Score    4.814570
# Governance Risk Score     6.398013
# Social Risk Score         8.725166
# dtype: float64

# %%
y_train
# Out:
# 393    11.0
# 36     13.0
# 452    16.0
# 346    12.0
# 303    25.0
#        ...
# 201    16.0
# 168    12.0
# 185    19.0
# 35     16.0
# 129    26.0
# Name: Total ESG Risk score, Length: 352, dtype: float64

# %%
y_train.mean()
# Out:
# 20.806818181818183

# %%
y_test
# Out:
# 494    26.0
# 420    25.0
# 237    19.0
# 103    24.0
# 175    16.0
#        ...
# 399    26.0
# 457    29.0
# 464    18.0
# 15     26.0
# 426    26.0
# Name: Total ESG Risk score, Length: 151, dtype: float64

# %%
y_test.mean()
# Out:
# 20.344370860927153

# %%
#X = caracteristicas para entrenar el modelo
#y = ESG Risk para entrenar el modelo

print('Dimensiones de X de entrenamiento: {}'.format(X_train.shape))
print('Dimensiones de y de entrenamiento: {}\n'.format(y_train.shape))

#Prueba, el modelo no lo sabe
print('Dimensiones de X de prueba: {}'.format(X_test.shape))
print('Dimensiones de y de prueba: {}'.format(y_test.shape))
# Out:
# Dimensiones de X de entrenamiento: (352, 3)
# Dimensiones de y de entrenamiento: (352,)
#
# Dimensiones de X de prueba: (151, 3)
# Dimensiones de y de prueba: (151,)

# %% [markdown]
# ## Procesamiento

# %% [markdown]
# ## Modelo de Regresión

# %%
modelo = LinearRegression()

# %%
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Se almacena el resultado en y_predict_test
y_predict_test = modelo.predict(X_test)
y_predict_test
# Out:
# array([26.73582744, 25.12272414, 19.01593618, 24.05212691, 16.2245866 ,
#        25.66469246, 21.42268802, 11.50745071, 14.52800188, 24.10763648,
#        14.5015363 , 25.86613887, 25.07546876, 21.14400227, 13.4505766 ,
#         9.63032935, 31.9765959 , 14.52800188, 13.63299561, 14.39124288,
#        21.24897287, 14.52800188, 11.39760477, 13.55643894, 26.31940402,
#        14.52800188, 36.26304431, 14.35613502, 37.01178726, 28.55061774,
#        16.32196175, 22.03648735, 19.71008881, 28.23574541, 19.31981207,
#        14.52800188, 30.04529981, 31.07652193, 14.88164676, 14.52800188,
#        23.27028385, 22.16746949, 19.14794521, 14.52800188, 22.326971  ,
#        11.3024903 , 14.52800188, 23.20606384, 26.86500295, 18.75540241,
#        14.52800188, 23.64933553, 20.00057684, 15.85225417, 14.52800188,
#        29.18084277, 14.52800188, 28.60855283, 34.67002937, 13.90211225,
#        26.90820556, 12.8756104 , 24.48437028, 35.87614205, 15.77846943,
# ...

# %%
# y_test son los valores reales de la variable dependiente en el conjunto de prueba
# y_predict_test son las predicciones del modelo en el conjunto de prueba

# Genera datos de ejemplo para la variable 'grupo' (asumiendo que es una lista de valores)
grupo = np.random.randint(0, 3, size=len(y_test))  # Ejemplo: valores aleatorios entre 0 y 2


# Crear un gráfico de dispersión y colorear los puntos por grupo
plt.scatter(y_test, y_predict_test, c=grupo, cmap='viridis')

# Etiquetas de los ejes
plt.xlabel("Valores Reales")
plt.ylabel("Predicciones")

# Título del gráfico
plt.title("Gráfico de Regresión: Valores Reales vs. Predicciones")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Se observa un gráfico de dispersión donde tanto los valores reales como las predicciones siguen una línea recta que va subiendo constantemente de 0 a 40, esto sugiere que hay una fuerte correlación positiva entre las variables e indica un buen ajuste del modelo a los datos o que el modelo está capturando eficazmente la relación subyacente entre las variables.

# %% [markdown]
# ## Métricas de ayuda
#
# Mean Absolute Error (Error Absoluto Medio) y Coeficiente de determinación (R-cuadrado)

# %% [markdown]
# Para verificar este modelo se toman estas 2 métricas que ayudan a evaluar el rendimiento para poder determinar cuánta variabilidad en la variable dependiente (la variable que se está tratando de predecir) puede ser explicada por el modelo de regresión.

# %%
from sklearn.metrics import mean_absolute_error, r2_score

X = risk_8[['Environment Risk Score', 'Governance Risk Score', 'Social Risk Score']]

y = risk_8['Total ESG Risk score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 99)


modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)

y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)

mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)

mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)

print('Prueba - Error Absoluto Medio:',round(mae_test,2), 'y Coeficiente de determinación:', round(r2_test,2))

print('Entrenamiento - Error Absoluto Medio:', round(mae_train,2), 'y Coeficiente de determinación:', round(r2_train,2))
# Out:
# Prueba - Error Absoluto Medio: 0.6 y Coeficiente de determinación: 0.99
# Entrenamiento - Error Absoluto Medio: 0.54 y Coeficiente de determinación: 0.99

# %% [markdown]
# Con los siguientes resultados se llega a las siguientes conclusiones de este modelo:

# %% [markdown]
# **Mean Absolute Error (Error Absoluto Medio) en datos de prueba.** El valor es aproximadamente 0.60. Un valor más bajo indica que el modelo tiene un error absoluto medio más pequeño, lo que significa que las predicciones son más cercanas a los valores reales.
#
# **Coeficiente de determinación (R-cuadrado) en datos de prueba.** El valor es aproximadamente 0.9873. Un valor cercano a 1 sugiere que el modelo se ajusta muy bien a los datos de prueba y es capaz de explicar la mayor parte de la variabilidad en los valores observados.
#
# Estos resultados indican que el modelo de regresión tiene un rendimiento **muy bueno en ambos conjuntos de datos (entrenamiento y prueba)**. El valor bajo de mae indica que las predicciones del modelo están muy cerca de los valores reales, y el valor alto de r2 sugiere que el modelo es altamente capaz de explicar la variabilidad en los datos.

# %% [markdown]
# ## Modelo Árbol de desición

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor

# Se crea una variable objeto que contiene toda la información del modelo

tree = DecisionTreeClassifier(max_depth= 8, # Define la profundidad máxima del árbol
                              random_state= 45, # Define la semilla para las variables aleatorias requeridas
                               max_leaf_nodes = 4 # Hay 1 variable objetivo y 3 variables más
                              )

# Usando este objeto vamos a hacer el entrenamiento del modelo, para ello usamos el método fit, este se encarga de ajustar el modelo usando los datos de entrenamiento
tree.fit(X_train,y_train) #entrenamos

print(type(tree))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>

# %% [markdown]
# ### Evaluación del desempeño del modelo

# %%
from sklearn.metrics import accuracy_score

y_pred_tree = tree.predict(X_test) #predicción
acc_tree_test = accuracy_score(y_test, y_pred_tree) #Compara los resultados

print('Exactitud en partición de prueba: {:3f}'.format(acc_tree_test))

y_pred_tree_train = tree.predict(X_train)
acc_tree_train = accuracy_score(y_train, y_pred_tree_train)
print('Exactitud en partición de entrenamiento: {:3f}'.format(acc_tree_train))
# Out:
# Exactitud en partición de prueba: 0.218543
# Exactitud en partición de entrenamiento: 0.204545

# %% [markdown]
# Hay 21% de exactitud en mi participación de prueba, muy mal modelo.

# %% [markdown]
# ### Importancia de las variables para el modelo

# %%
plt.bar(x= tree.feature_names_in_ ,height = tree.feature_importances_)
plt.xlabel('Variables')
plt.ylabel('Importancia relativa')
plt.xticks(rotation=0, fontsize=9)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Environment Risk Score'),
#   Text(1, 0, 'Governance Risk Score'),
#   Text(2, 0, 'Social Risk Score')])

# %% [markdown]
# la siguiente gráfica puede dar un acercamiento de la lógica empleada por el modelo para tomar decisiones y darle importancia 0 a la variable 'Social Risk Score'

# %%
sns.pairplot(data = risk_8, hue = 'Total ESG Risk score', corner = True)
plt.show()

# %% [markdown]
# Podemos ver cómo se decidió por calificar más alto a estas dos variables, Social Risk Score tiene sus datos entre -10 y 30 puntos, en cambio las otras dos variables no tienen números negativos.

# %% [markdown]
# ### Visualización y profundidad del modelo

# %%
from sklearn.tree import export_graphviz

# Convierte las clases y características en listas de cadenas de texto
class_names = [str(class_name) for class_name in tree.classes_]
feature_names = [str(feature_name) for feature_name in tree.feature_names_in_]

# Luego, utiliza estas listas en export_graphviz
export_graphviz(tree,
                out_file="tree.dot",
                class_names=class_names,
                feature_names=feature_names,
                impurity=False,
                filled=True)

# %%
import graphviz

with open("tree.dot") as f:dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %% [markdown]
# Se puede notar que desde que los niveles que tiene el modelo, la variable 'Social Risk level' no aparece en estos.

# %% [markdown]
# ### Cambiar la profundidad del árbol

# %% [markdown]
# Por medio del siguiente código se va a iterar la profundidad para saber, cuál es mejor para el modelo.

# %%
#profundidad

profundidad = range(1,10) #Se itera para tener como resultado el mejor maodelo.
exactitud_prueba = []
exactitud_entrenamiento = []

for i in profundidad:
  tree = DecisionTreeClassifier(random_state = 0, max_depth = i)
  tree.fit(X_train,y_train)

  y_pred = tree.predict(X_test)
  y_pred2 = tree.predict(X_train)

  metrica = accuracy_score(y_test,y_pred)
  metrica2 = accuracy_score(y_train,y_pred2)

  exactitud_prueba.append(metrica)
  exactitud_entrenamiento.append(metrica2)

print('Profundidad:', profundidad)
print('Exactitud de prueba:', exactitud_prueba)
print('Exactitud de entrenamiento:',exactitud_entrenamiento)
# Out:
# Profundidad: range(1, 10)
# Exactitud de prueba: [0.2119205298013245, 0.2185430463576159, 0.23841059602649006, 0.271523178807947, 0.2980132450331126, 0.33774834437086093, 0.32450331125827814, 0.3509933774834437, 0.3509933774834437]
# Exactitud de entrenamiento: [0.19602272727272727, 0.21875, 0.26988636363636365, 0.3494318181818182, 0.4403409090909091, 0.5369318181818182, 0.6221590909090909, 0.7102272727272727, 0.7926136363636364]

# %% [markdown]
# Se realiza una gráfica para mejorar observar mejor la exactitud del modelo

# %%
plt.plot(profundidad,exactitud_prueba, marker = 'x')
plt.plot(profundidad,exactitud_entrenamiento, marker = 'o')
plt.xlabel('Nivel')
plt.ylabel('Exactitud en %')
# Out:
# Text(0, 0.5, 'Exactitud en %')

# %% [markdown]
# Exactitud desde el nivel 6 en la prueba, donde se tiene una exactitud de más del 30%, lo cual no es óptimo,
# en cambio el modelo de entrenamiento llega a un 80% de exactitud en el nivel 9

# %% [markdown]
# ## Modelo de vecinos más cercanos

# %%
risk_8.columns
# Out:
# Index(['Symbol', 'Name', 'Address', 'Sector', 'Industry',
#        'Full Time Employees', 'Description', 'Total ESG Risk score',
#        'Environment Risk Score', 'Governance Risk Score', 'Social Risk Score',
#        'Controversy Level', 'Controversy Score', 'ESG Risk Percentile',
#        'ESG Risk Level'],
#       dtype='object')

# %%
risk_8.describe(include='object')
# Out:
#        Symbol                      Name  \
# count     503                       503
# unique    503                       503
# top         A  Agilent Technologies Inc
# freq        1                         1
#
#                                                   Address      Sector  \
# count                                                 503         503
# unique                                                498          11
# top     1211 Avenue of the Americas\nNew York, NY 1003...  Technology
# freq                                                    4          77
#
#                             Industry Full Time Employees  \
# count                            503                 503
# unique                           114                 398
# top     Utilities—Regulated Electric              25,000
# freq                              25                  12
#
#                                               Description Controversy Level  \
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder #Escalan las variables cuantitativas y categorícas respectivamente
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier  # Cambiamos el clasificador

# Columnas cualitativas
categorical_features = ['Symbol', 'Name', 'Address', 'Sector', 'Industry',
       'Full Time Employees', 'Description', 'Controversy Level', 'ESG Risk Percentile',
       'ESG Risk Level']

categorical_transformer = Pipeline(steps=[
# Incluye solo un paso 'onehot'
    ('onehot', OneHotEncoder(sparse=False, handle_unknown='ignore'))
])

categorical_transformer
# Out:
# Pipeline(steps=[('onehot',
#                  OneHotEncoder(handle_unknown='ignore', sparse=False))])

# %%
#Pipeline llamado preprocessor
preprocessor = ColumnTransformer(
    transformers=[
#Se renombra la variable a 'cat' y sólo afecta las categorical_features
        ('cat', categorical_transformer, categorical_features)
    ])
preprocessor
# Out:
# ColumnTransformer(transformers=[('cat',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  ['Symbol', 'Name', 'Address', 'Sector',
#                                   'Industry', 'Full Time Employees',
#                                   'Description', 'Controversy Level',
#                                   'ESG Risk Percentile', 'ESG Risk Level'])])

# %%
#Se elimina las columnas no clasificatoría
remove_col = risk_8.drop(columns=['Symbol', 'Address','Full Time Employees','ESG Risk Percentile','ESG Risk Level'])

# %%
X_2 = risk_8.drop(columns = ['Total ESG Risk score'])

y_2 = risk_8['Total ESG Risk score']

print('Dimensiones de X: {}'.format(X_2.shape))
print('Dimensiones de y: {}'.format(y_2.shape))
# Out:
# Dimensiones de X: (503, 14)
# Dimensiones de y: (503,)

# %%
#El Random State o semilla siempre me traerá el mismo orden (X_test)por eso para este modelo no la debo cambiar
X_2_train, X_2_test, y_2_train, y_2_test = train_test_split(X_2,y_2,test_size=0.30,random_state=99)

# %%
# Se crea un regresor
regresor = KNeighborsRegressor(n_neighbors = 7) # número de vecinos

pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('model', regresor)])

# %%
# Ajusta el modelo K-NN a tus datos de entrenamiento
pipeline.fit(X_2_train, y_2_train)

# Realiza predicciones en el conjunto de prueba
y_pred = pipeline.predict(X_2_test)

# Crea un gráfico de dispersión para comparar predicciones con valores reales
plt.figure(figsize=(8, 6))
plt.scatter(y_2_test, y_2_pred, alpha=0.5)
plt.xlabel('Valores Reales')
plt.ylabel('Predicciones')
plt.title('Valores Reales vs. Predicciones')

# Agrega una línea de referencia de 45 grados (diagonal) para comparación
plt.plot([min(y_2_test), max(y_2_test)], [min(y_2_test), max(y_2_test)], linestyle='--', color='red', linewidth=2)

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning:
#
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.

# %% [markdown]
# En este gráfico se puede visualizar cómo se comporta el modelo de K-NN en términos de predicciones en comparación con los valores reales.
# Las predicciones están cerca de la línea de referencia de 45 grados, esto quiere decir que el modelo se ajusta bien a los datos de prueba y hace buenas predicciones.

# %% [markdown]
# ### Entrenamiento del modelo

# %%
# pipeline para entrenar el modelo
pipeline.fit(X_2_train, y_2_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning:
#
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['Symbol', 'Name', 'Address',
#                                                    'Sector', 'Industry',
#                                                    'Full Time Employees',
#                                                    'Description',
# ...

# %% [markdown]
# ### Predicciones

# %%
y_2_pred = pipeline.predict(X_2_test)

# %%
# y_2_pred es el Total ESG Risk score predicho para el ESG del conjunto de prueba
y_2_pred = pipeline.predict(X_2_test)
y_2_pred
# Out:
# array([23.71428571, 24.71428571, 15.28571429, 21.71428571, 17.        ,
#        20.42857143, 24.42857143, 12.71428571, 22.85714286, 22.57142857,
#        13.57142857, 22.57142857, 24.85714286, 16.71428571, 12.85714286,
#        17.57142857, 29.85714286, 16.        , 13.        , 15.42857143,
#        19.71428571, 16.71428571, 15.42857143, 14.        , 22.28571429,
#        17.57142857, 33.14285714, 13.57142857, 35.85714286, 24.42857143,
#        16.28571429, 21.28571429, 20.        , 23.71428571, 27.14285714,
#        16.        , 29.42857143, 30.14285714, 16.28571429, 18.28571429,
#        17.        , 21.42857143, 15.        , 16.        , 22.28571429,
#        12.85714286, 17.        , 23.57142857, 24.28571429, 16.71428571,
#        16.        , 20.        , 18.42857143, 14.14285714, 17.14285714,
#        25.42857143, 19.57142857, 23.14285714, 30.        , 14.71428571,
#        18.42857143, 13.        , 24.14285714, 35.28571429, 14.42857143,
# ...

# %%
# Con el siguiente dataframe puede comparar manualmente los resultados obtenidos

comp = y_2_test == y_2_pred

pd.DataFrame({'Etiqueta real': y_2_test,'Etiqueta predicha': y_2_pred, 'Comparación' : comp })
# Out:
#      Etiqueta real  Etiqueta predicha  Comparación
# 494           26.0          23.714286        False
# 420           25.0          24.714286        False
# 237           19.0          15.285714        False
# 103           24.0          21.714286        False
# 175           16.0          17.000000        False
# ..             ...                ...          ...
# 399           26.0          23.571429        False
# 457           29.0          24.142857        False
# 464           18.0          16.285714        False
# 15            26.0          25.571429        False
# 426           26.0          23.428571        False
#
# [151 rows x 3 columns]

# %%
#y_2_test contiene el valor Total ESG Risk score real
y_2_test
# Out:
# 494    26.0
# 420    25.0
# 237    19.0
# 103    24.0
# 175    16.0
#        ...
# 399    26.0
# 457    29.0
# 464    18.0
# 15     26.0
# 426    26.0
# Name: Total ESG Risk score, Length: 151, dtype: float64

# %%
#Comparación de y_2_test y y_2_pred para ver que tan similares son y si se parecen o no

#Se calcula el score para este modelo de regresión

score_entrenamiento = pipeline.score(X_2_train, y_2_train)
score_prueba = pipeline.score(X_2_test, y_2_test)
print('Score entrenamiento:',score_entrenamiento,'Score prueba',score_prueba)

# Es una medida de desempeño, entre mayor es mejor [0,1]
# Out:
# Score entrenamiento: 0.8010420121279673 Score prueba 0.7732712750364357

# %% [markdown]
# Tiene un 77% de desempeño, pero podemos mejor K para optimizar el modelo.

# %% [markdown]
# ### Experimentos para muchos escenarios posibles

# %%
#El máximo de vecinos que puedo ver tiene que ver con la longitud de prueba que son 151
y_2_test.shape
# Out:
# (151,)

# %%
k_value = np.linspace(1,151)#min de 1 a máx 151 vecinos
k_value
# Out:
# array([  1.        ,   4.06122449,   7.12244898,  10.18367347,
#         13.24489796,  16.30612245,  19.36734694,  22.42857143,
#         25.48979592,  28.55102041,  31.6122449 ,  34.67346939,
#         37.73469388,  40.79591837,  43.85714286,  46.91836735,
#         49.97959184,  53.04081633,  56.10204082,  59.16326531,
#         62.2244898 ,  65.28571429,  68.34693878,  71.40816327,
#         74.46938776,  77.53061224,  80.59183673,  83.65306122,
#         86.71428571,  89.7755102 ,  92.83673469,  95.89795918,
#         98.95918367, 102.02040816, 105.08163265, 108.14285714,
#        111.20408163, 114.26530612, 117.32653061, 120.3877551 ,
#        123.44897959, 126.51020408, 129.57142857, 132.63265306,
#        135.69387755, 138.75510204, 141.81632653, 144.87755102,
#        147.93877551, 151.        ])

# %%
#Deben ser números enteros
k_value = np.linspace(1,151,dtype='int')
k_value
# Out:
# array([  1,   4,   7,  10,  13,  16,  19,  22,  25,  28,  31,  34,  37,
#         40,  43,  46,  49,  53,  56,  59,  62,  65,  68,  71,  74,  77,
#         80,  83,  86,  89,  92,  95,  98, 102, 105, 108, 111, 114, 117,
#        120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 151])

# %%
#Se reutiliza el código
k_value = np.linspace(1,151,dtype='int')
score_prueba_lista = []
score_entrenamiento_lista = []

for  vecinos in k_value:

  regresor = KNeighborsRegressor(vecinos)  #Itere por vecinos
  pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('model', regresor)])
  pipeline.fit(X_2_train, y_2_train)

  #Medimos métricas
  score_entrenamiento = pipeline.score(X_2_train, y_2_train)
  score_entrenamiento_lista.append(score_entrenamiento)

  score_prueba = pipeline.score(X_2_test, y_2_test)
  score_prueba_lista.append(score_prueba)
  print(f'Se entrenó el modelo con {vecinos} vecinos')
# Out:
# Se entrenó el modelo con 1 vecinos
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning:
#
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning:
#
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning:
#
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
# Se entrenó el modelo con 4 vecinos
# Se entrenó el modelo con 7 vecinos
# Se entrenó el modelo con 10 vecinos
# ...

# %%
score_prueba_lista
# Out:
# [0.5082627472059014,
#  0.7770110095824143,
#  0.7732712750364357,
#  0.7682705688284247,
#  0.7567744367029072,
#  0.73341364894561,
#  0.7334626197942982,
#  0.7075284342218273,
#  0.6960829803718052,
#  0.6794844728802127,
#  0.6662532202026612,
#  0.6567340393731133,
#  0.6566613838625364,
#  0.6308613874576021,
#  0.6251671093213684,
#  0.6317165320884028,
#  0.5954540967378915,
#  0.5899214640866864,
#  0.5966350823652447,
#  0.5682959153384021,
#  0.5667616021849518,
#  0.5401415659059818,
#  0.5295923067924619,
#  0.5111326552881904,
#  0.5098581165732581,
#  0.508798183530472,
#  0.4934253994796397,
#  0.48192009143122383,
#  0.47716385980318166,
#  0.4713327316712622,
#  0.46087598467958724,
#  0.44236342598998524,
#  0.4338497784175196,
#  0.4194766525862469,
#  0.40868671031513826,
#  0.39571947124404916,
#  0.39359433098315444,
#  0.389319287048951,
#  0.38189389438052224,
#  0.3765472172796487,
#  0.3683915856058092,
#  0.3598739767164909,
#  0.34269595611694215,
# ...

# %%
plt.plot(k_value,score_prueba_lista, color = 'red')
plt.plot(k_value,score_entrenamiento_lista)
plt.xlabel('Numero de vecinos')
plt.ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %%
results = pd.DataFrame({'k':k_value,
              'score_prueba':score_prueba_lista,
              'score_entrenamiento':score_entrenamiento_lista
              })

# %%
results.sort_values(by='score_prueba', ascending = False)
# Out:
#       k  score_prueba  score_entrenamiento
# 1     4      0.777011             0.822433
# 2     7      0.773271             0.801042
# 3    10      0.768271             0.779310
# 4    13      0.756774             0.765817
# 6    19      0.733463             0.727686
# 5    16      0.733414             0.735918
# 7    22      0.707528             0.701609
# 8    25      0.696083             0.674291
# 9    28      0.679484             0.669511
# 10   31      0.666253             0.635959
# 11   34      0.656734             0.631995
# 12   37      0.656661             0.625132
# 15   46      0.631717             0.599784
# 13   40      0.630861             0.610405
# 14   43      0.625167             0.597228
# 18   56      0.596635             0.543402
# 16   49      0.595454             0.563560
# 17   53      0.589921             0.553288
# 19   59      0.568296             0.528960
# 20   62      0.566762             0.513030
# 21   65      0.540142             0.490913
# ...

# %% [markdown]
# Se modifica que el número de vecinos debe ser en vez de 7 (que se vió anterior) es 4 y va a llegar hasta el 78% de desempeño.
# El score de entrenamiento es del 82% solo difiere en un 5% con el score de prueba

# %% [markdown]
# ## Conclusiones
#
# - En el **modelo de vecino más cercano** el score de prueba es del 77% cuando se colocan 4 vecinos, este puede ser un buen modelo a tomar porque no necesita tanto tiempo para predecir y es buen porcentaje.
#
# - El **modelo de árbol de desición** no es una buena desición para pasar a producción ya que el conjunto de prueba no tiene la exactitud esperada con el pasar de los niveles, como si lo hizo el conjunto de entrenamiento que su exactitud creció a partir del **nivel 2** hasta llegar al **100%** con el pasar de los niveles.
#
# - En el conjunto de prueba del **árbol de desición** pudo influir en su pésimo rendimiento que el modelo no le dió importancia a la variable 'Social Risk Score'. Se podría verificar con el conjunto de entrenamiento que tiene la predicción óptima ya que el modelo le dió importancia y por eso su mejor desempeño.
#
# - El **modelo de Regresión** es un buen modelo porque tanto las predicciones como los valores reales tienen correlación positiva y lo afirma la métrica **coeficiente de determinación** puesto su valor es del **98%** en el conjunto de prueba, así que este es el que pasaría a producción.
#
# - En los modelos que automaticé para que tomen desiciones, en su mayoría el comjunto de entrenamiento tenía mejores predicciones que los conjuntos de prueba, así que en este caso, la correción en las palanquillas puede ayudar a mejorar los datos de predicción para los conjuntos de pruebas
